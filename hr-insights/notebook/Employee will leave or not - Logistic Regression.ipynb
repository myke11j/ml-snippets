# %% [markdown]
# # We're trying to find if an employee will leave on not based on independent variables. For this we're using Logistic Regression

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('../HR_comma_sep.csv')
[m, n] = df.shape

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
dfLeftOne = df[ df['left'] == 1 ]
dfLeftZero = df[ df['left'] == 0 ]

# %%
# trainOne = dfLeftOne.iloc[:(m-501), :]
# testOne = dfLeftZero.iloc[(m-500):, :]

# trainOne = dfLeftOne.iloc[:(m-501), :]
# testOne = dfLeftZero.iloc[(m-500):, :]

# %%
X1 = dfLeftOne['satisfaction_level']
y1 = dfLeftOne['last_evaluation']

X2 = dfLeftZero['satisfaction_level']
y2 = dfLeftZero['last_evaluation']

X2 = dfLeftZero['satisfaction_level']
y2 = dfLeftZero['average_montly_hours']

# %%
# plt.scatter(X1, y1, color='g')
plt.scatter(X1, y1, color='b')
print(np.corrcoef(X1, y1))
plt.show()
# Out:
# [[1.         0.18229492]
#  [0.18229492 1.        ]]

# %% [markdown]
# ## Checking correlation of every field

# %%
dfLeftZero = dfLeftZero.iloc[:,:n-2]
np.seterr(divide='ignore', invalid='ignore')
for column in dfLeftZero:
    for column2 in dfLeftZero:
        X_temp = dfLeftZero[column]
        y_temp = dfLeftZero[column2]
        print(column, column2, np.corrcoef(X_temp, y_temp))
        plt.scatter(X_temp, y_temp)
        plt.xlabel(column)
        plt.ylabel(column2)
        plt.show()
# Out:
# satisfaction_level satisfaction_level [[1. 1.]
#  [1. 1.]]
# satisfaction_level last_evaluation [[1.         0.08635699]
#  [0.08635699 1.        ]]
# satisfaction_level number_project [[ 1.         -0.09279879]
#  [-0.09279879  1.        ]]
# satisfaction_level average_montly_hours [[1.        0.0553539]
#  [0.0553539 1.       ]]
# satisfaction_level time_spend_company [[ 1.         -0.16879095]
#  [-0.16879095  1.        ]]
# satisfaction_level Work_accident [[ 1.         -0.00312844]
#  [-0.00312844  1.        ]]
# satisfaction_level left [[ 1. nan]
#  [nan nan]]
# satisfaction_level promotion_last_5years [[1.         0.00122806]
#  [0.00122806 1.        ]]
# last_evaluation satisfaction_level [[1.         0.08635699]
#  [0.08635699 1.        ]]
# last_evaluation last_evaluation [[1. 1.]
#  [1. 1.]]
# last_evaluation number_project [[1.         0.04030569]
#  [0.04030569 1.        ]]
# last_evaluation average_montly_hours [[1.         0.09030389]
#  [0.09030389 1.        ]]
# ...
